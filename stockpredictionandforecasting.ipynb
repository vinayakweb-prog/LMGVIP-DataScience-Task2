# %% [markdown]
# #LetsGrowMoreVIP
# #NAME - VIVEK LONE
# #Beginner Level Task 2 - Stock Market Prediction And Forecasting Using Stacked 3LSTM

# %% [markdown]
# ##IMPORTING THE MODULES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings('ignore')

# %% [markdown]
# ###LOADING THE DATASET THROUGH URL

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')
data.head()
# Out:
#          Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-09-28  234.05  235.95  ...  233.75               3069914          7162.35
# 1  2018-09-27  234.55  236.80  ...  233.25               5082859         11859.95
# 2  2018-09-26  240.00  240.00  ...  234.25               2240909          5248.60
# 3  2018-09-25  233.30  236.75  ...  236.10               2349368          5503.90
# 4  2018-09-24  233.55  239.20  ...  233.30               3423509          7999.55
#
# [5 rows x 8 columns]

# %%
data.shape
# Out:
# (2035, 8)

# %%
data.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity      int64
# Turnover (Lacs)         float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %% [markdown]
# ###SUMMARISING THE DATASET

# %%
data.describe()
# Out:
#               Open         High  ...  Total Trade Quantity  Turnover (Lacs)
# count  2035.000000  2035.000000  ...          2.035000e+03      2035.000000
# mean    149.713735   151.992826  ...          2.335681e+06      3899.980565
# std      48.664509    49.413109  ...          2.091778e+06      4570.767877
# min      81.100000    82.800000  ...          3.961000e+04        37.040000
# 25%     120.025000   122.100000  ...          1.146444e+06      1427.460000
# 50%     141.500000   143.400000  ...          1.783456e+06      2512.030000
# 75%     157.175000   159.400000  ...          2.813594e+06      4539.015000
# max     327.700000   328.750000  ...          2.919102e+07     55755.080000
#
# [8 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.head()
# Out:
#         Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0 2018-09-28  234.05  235.95  ...  233.75               3069914          7162.35
# 1 2018-09-27  234.55  236.80  ...  233.25               5082859         11859.95
# 2 2018-09-26  240.00  240.00  ...  234.25               2240909          5248.60
# 3 2018-09-25  233.30  236.75  ...  236.10               2349368          5503.90
# 4 2018-09-24  233.55  239.20  ...  233.30               3423509          7999.55
#
# [5 rows x 8 columns]

# %%
data['Date'].value_counts()
# Out:
# 2015-09-24    1
# 2016-12-22    1
# 2017-11-14    1
# 2016-04-28    1
# 2012-08-16    1
#              ..
# 2015-11-06    1
# 2011-08-25    1
# 2012-10-15    1
# 2015-01-27    1
# 2011-10-13    1
# Name: Date, Length: 2035, dtype: int64

# %%
df = data.sort_values('Date')
df.head()
# Out:
#            Date   Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 2034 2010-07-21  122.1  123.00  ...  121.55                658666           803.56
# 2033 2010-07-22  120.3  122.00  ...  120.90                293312           355.17
# 2032 2010-07-23  121.8  121.95  ...  120.65                281312           340.31
# 2031 2010-07-26  120.1  121.00  ...  117.60                658440           780.01
# 2030 2010-07-27  117.6  119.50  ...  118.65                586100           694.98
#
# [5 rows x 8 columns]

# %%
df.reset_index(inplace=True)

# %%
df_close = df['Close']
df_close
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# ###DATA VISUALISATION

# %%
plt.plot(df['Close'])

# %%
df['High'].hist()

# %%
plt.figure(figsize=(20,10))
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7f0525ae8550>,
#  <matplotlib.lines.Line2D at 0x7f05255b1710>,
#  <matplotlib.lines.Line2D at 0x7f05255b19d0>,
#  <matplotlib.lines.Line2D at 0x7f05255b1b90>,
#  <matplotlib.lines.Line2D at 0x7f05255b1d50>,
#  <matplotlib.lines.Line2D at 0x7f05255b1f10>,
#  <matplotlib.lines.Line2D at 0x7f05254f9190>,
#  <matplotlib.lines.Line2D at 0x7f05254f9350>,
#  <matplotlib.lines.Line2D at 0x7f05255b1d10>]

# %%
sns.pairplot(df)

# %% [markdown]
# ##Applying MinMaxScalar

# %%
scalar = MinMaxScaler()
df_close=scalar.fit_transform(np.array(df_close).reshape(-1,1))
df_close
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# ##Splitting the data

# %%
training_size = int(len(df_close)*0.70)
test_size = len(df_close) - training_size
train, test = df_close[0 : training_size, :], df_close[training_size : len(df_close), :1]

# %%
def create_matrix(ds, time_step=1):
    dataX, dataY = [], []
    for i in range(len(ds)-time_step-1):
        a = ds[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(ds[i+time_step,0])
    return np.array(dataX), np.array(dataY)

# %%
time_step=100
X_train, y_train = create_matrix(train, time_step)
X_test, y_test = create_matrix(test, time_step)

# %%
X_train.shape
# Out:
# (1323, 100)

# %%
y_train.shape
# Out:
# (1323,)

# %%
X_test.shape
# Out:
# (510, 100)

# %%
y_test.shape
# Out:
# (510,)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ##Creating LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs=60, batch_size=64, verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 9s 219ms/step - loss: 0.0096 - val_loss: 0.0020
# Epoch 2/60
# 19/19 [==============================] - 3s 156ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 3/60
# 19/19 [==============================] - 3s 156ms/step - loss: 9.8547e-04 - val_loss: 0.0013
# Epoch 4/60
# 19/19 [==============================] - 3s 155ms/step - loss: 8.9521e-04 - val_loss: 0.0012
# Epoch 5/60
# 19/19 [==============================] - 3s 156ms/step - loss: 8.6400e-04 - val_loss: 0.0012
# Epoch 6/60
# 19/19 [==============================] - 3s 155ms/step - loss: 8.6335e-04 - val_loss: 0.0012
# Epoch 7/60
# 19/19 [==============================] - 3s 156ms/step - loss: 8.2843e-04 - val_loss: 0.0011
# Epoch 8/60
# 19/19 [==============================] - 3s 155ms/step - loss: 7.7627e-04 - val_loss: 0.0010
# Epoch 9/60
# 19/19 [==============================] - 3s 156ms/step - loss: 7.5955e-04 - val_loss: 9.4996e-04
# Epoch 10/60
# 19/19 [==============================] - 3s 155ms/step - loss: 7.2035e-04 - val_loss: 8.9848e-04
# Epoch 11/60
# 19/19 [==============================] - 3s 154ms/step - loss: 7.0070e-04 - val_loss: 8.5465e-04
# Epoch 12/60
# 19/19 [==============================] - 3s 155ms/step - loss: 6.8859e-04 - val_loss: 7.9192e-04
# Epoch 13/60
# 19/19 [==============================] - 3s 156ms/step - loss: 6.5300e-04 - val_loss: 7.7187e-04
# Epoch 14/60
# 19/19 [==============================] - 3s 156ms/step - loss: 6.3270e-04 - val_loss: 8.5251e-04
# Epoch 15/60
# 19/19 [==============================] - 3s 155ms/step - loss: 6.2730e-04 - val_loss: 6.8826e-04
# Epoch 16/60
# 19/19 [==============================] - 3s 156ms/step - loss: 6.2345e-04 - val_loss: 7.8723e-04
# Epoch 17/60
# 19/19 [==============================] - 3s 155ms/step - loss: 6.3556e-04 - val_loss: 6.6566e-04
# Epoch 18/60
# 19/19 [==============================] - 3s 155ms/step - loss: 6.3058e-04 - val_loss: 6.3429e-04
# Epoch 19/60
# 19/19 [==============================] - 3s 156ms/step - loss: 5.5848e-04 - val_loss: 6.7920e-04
# Epoch 20/60
# 19/19 [==============================] - 3s 156ms/step - loss: 6.0959e-04 - val_loss: 0.0011
# Epoch 21/60
# 19/19 [==============================] - 3s 155ms/step - loss: 6.3016e-04 - val_loss: 5.8686e-04
# Epoch 22/60
# 19/19 [==============================] - 3s 156ms/step - loss: 5.3955e-04 - val_loss: 6.2828e-04
# Epoch 23/60
# 19/19 [==============================] - 3s 156ms/step - loss: 6.0861e-04 - val_loss: 5.7375e-04
# Epoch 24/60
# 19/19 [==============================] - 3s 156ms/step - loss: 5.5978e-04 - val_loss: 5.5797e-04
# Epoch 25/60
# 19/19 [==============================] - 3s 158ms/step - loss: 5.1764e-04 - val_loss: 7.0791e-04
# Epoch 26/60
# 19/19 [==============================] - 3s 156ms/step - loss: 5.3253e-04 - val_loss: 5.2193e-04
# Epoch 27/60
# 19/19 [==============================] - 3s 158ms/step - loss: 5.0698e-04 - val_loss: 5.0949e-04
# Epoch 28/60
# 19/19 [==============================] - 3s 155ms/step - loss: 4.7379e-04 - val_loss: 4.8295e-04
# Epoch 29/60
# 19/19 [==============================] - 3s 156ms/step - loss: 5.2416e-04 - val_loss: 4.8473e-04
# Epoch 30/60
# 19/19 [==============================] - 3s 154ms/step - loss: 5.2239e-04 - val_loss: 4.5257e-04
# Epoch 31/60
# 19/19 [==============================] - 3s 156ms/step - loss: 4.6341e-04 - val_loss: 5.6734e-04
# Epoch 32/60
# 19/19 [==============================] - 3s 155ms/step - loss: 4.6145e-04 - val_loss: 5.0601e-04
# Epoch 33/60
# 19/19 [==============================] - 3s 156ms/step - loss: 4.3689e-04 - val_loss: 4.2665e-04
# Epoch 34/60
# 19/19 [==============================] - 3s 158ms/step - loss: 4.1002e-04 - val_loss: 4.0204e-04
# Epoch 35/60
# 19/19 [==============================] - 3s 156ms/step - loss: 4.0416e-04 - val_loss: 4.3209e-04
# Epoch 36/60
# 19/19 [==============================] - 3s 155ms/step - loss: 3.8949e-04 - val_loss: 3.6667e-04
# Epoch 37/60
# 19/19 [==============================] - 3s 156ms/step - loss: 3.9161e-04 - val_loss: 3.5590e-04
# Epoch 38/60
# 19/19 [==============================] - 3s 156ms/step - loss: 3.6227e-04 - val_loss: 3.4090e-04
# Epoch 39/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.7244e-04 - val_loss: 3.6572e-04
# Epoch 40/60
# 19/19 [==============================] - 3s 157ms/step - loss: 3.5781e-04 - val_loss: 4.0516e-04
# Epoch 41/60
# 19/19 [==============================] - 3s 158ms/step - loss: 3.4095e-04 - val_loss: 3.1472e-04
# Epoch 42/60
# 19/19 [==============================] - 3s 156ms/step - loss: 3.1306e-04 - val_loss: 2.9527e-04
# Epoch 43/60
# 19/19 [==============================] - 3s 157ms/step - loss: 3.0378e-04 - val_loss: 2.8559e-04
# Epoch 44/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.9097e-04 - val_loss: 2.7392e-04
# Epoch 45/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.7900e-04 - val_loss: 2.5628e-04
# Epoch 46/60
# 19/19 [==============================] - 3s 160ms/step - loss: 2.8170e-04 - val_loss: 2.4326e-04
# Epoch 47/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.6735e-04 - val_loss: 2.3050e-04
# Epoch 48/60
# 19/19 [==============================] - 3s 159ms/step - loss: 2.7894e-04 - val_loss: 2.3153e-04
# Epoch 49/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.6138e-04 - val_loss: 2.3958e-04
# Epoch 50/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.5924e-04 - val_loss: 2.8489e-04
# Epoch 51/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.4654e-04 - val_loss: 2.1816e-04
# Epoch 52/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.4828e-04 - val_loss: 2.1342e-04
# Epoch 53/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.3380e-04 - val_loss: 2.0543e-04
# Epoch 54/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.3580e-04 - val_loss: 1.9359e-04
# Epoch 55/60
# 19/19 [==============================] - 3s 158ms/step - loss: 2.3179e-04 - val_loss: 2.0735e-04
# Epoch 56/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.1398e-04 - val_loss: 2.2480e-04
# Epoch 57/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.1998e-04 - val_loss: 1.8042e-04
# Epoch 58/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.0871e-04 - val_loss: 1.9924e-04
# Epoch 59/60
# 19/19 [==============================] - 3s 157ms/step - loss: 2.2612e-04 - val_loss: 2.1923e-04
# Epoch 60/60
# 19/19 [==============================] - 3s 156ms/step - loss: 2.2395e-04 - val_loss: 1.9398e-04

# %% [markdown]
# ##PREDICTIONS

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ##INVERSE TRANSFORM ON PREDICTIONS

# %%
inverse_predictions = scalar.inverse_transform(predictions)

# %% [markdown]
# #EVALUATION

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
mse = math.sqrt(mean_squared_error(y_test, predictions))
print("The Mean Squared Error is:",mse)
# Out:
# The Mean Squared Error is: 0.03304924437947392

# %% [markdown]
# #Visualizing the Final Prediction

# %%
plt.figure(figsize=(10,10))
plt.plot(y_test, label="True Value")
plt.plot(predictions, label="LSTM Value")
plt.title("Stock Market Prediction and Forecasting using LSTM")
plt.xlabel("Time Scale")
plt.ylabel("Scaled Rupees")
plt.legend()
plt.show()
